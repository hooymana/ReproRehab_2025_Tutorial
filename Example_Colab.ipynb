# %% [markdown]
# <a href="https://colab.research.google.com/github/hooymana/ReproRehab_2025_Tutorial/blob/main/Example_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
data=read.csv("/content/healthcare-dataset-stroke-data.csv")
head(data)
# Out:
#   id    gender age hypertension heart_disease ever_married work_type
# 1  9046 Male   67  0            1             Yes          Private
# 2 51676 Female 61  0            0             Yes          Self-employed
# 3 31112 Male   80  0            1             Yes          Private
# 4 60182 Female 49  0            0             Yes          Private
# 5  1665 Female 79  1            0             Yes          Self-employed
# 6 56669 Male   81  0            0             Yes          Private
#   Residence_type avg_glucose_level bmi  smoking_status  stroke
# 1 Urban          228.69            36.6 formerly smoked 1
# 2 Rural          202.21            N/A  never smoked    1
# 3 Rural          105.92            32.5 never smoked    1
# 4 Urban          171.23            34.4 smokes          1
# 5 Rural          174.12            24   never smoked    1
# 6 Urban          186.21            29   formerly smoked 1

# %%
ggplot(data,aes(x=age,y=avg_glucose_level))+
  geom_point()
# Out:
# plot without title
